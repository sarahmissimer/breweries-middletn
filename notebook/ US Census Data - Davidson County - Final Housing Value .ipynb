# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from functools import reduce

# %matplotlib inline
# pd.options.display.max_columns = None
# pd.options.display.max_rows = None

# %%
housing_value_2020 = pd.read_csv("../data/housing_value_davidsoncountry2020.csv")
housing_value_2020

# %%
housing_value_2011 = pd.read_csv("../data/housing_value_davidsoncounty2011.csv")
housing_value_2011

# %%
housing_value_2015 = pd.read_csv("../data/housing_value_davidsoncounty2015.csv")

# %%
#2011 dataframe 
value_2011df = pd.DataFrame(housing_value_2011)

df2011value = housing_value_2011.iloc[[91, 92, 93, 94, 95, 96, 97, 98, 99], [0, 1, 5, 9, 13, 17, 21, 25, 29, 33, 37, 41, 45, 49,
                                                                        53, 57, 61, 65, 69, 73, 77, 81, 85, 89, 93, 97, 101,
                                                                        105, 109, 113, 117, 121, 125, 129, 133, 137, 141, 145, 
                                                                        149]]
                                                                         
df2011value.rename(columns={'ZCTA5 37013!!Estimate' : '37013', 'ZCTA5 37015!!Estimate':'37015',
                                'ZCTA5 37027!!Estimate':'37027', 'ZCTA5 37064!!Estimate':'37064',
                                 'ZCTA5 37072!!Estimate':'37072', 'ZCTA5 37076!!Estimate':'37076',
                                 'ZCTA5 37080!!Estimate':'37080', 'ZCTA5 37086!!Estimate':'37086',
                                 'ZCTA5 37115!!Estimate':'37115', 'ZCTA5 37122!!Estimate':'37122',
                                 'ZCTA5 37135!!Estimate':'37135', 'ZCTA5 37138!!Estimate':'37138',
                                 'ZCTA5 37143!!Estimate':'37143', 'ZCTA5 37189!!Estimate':'37189',
                               'ZCTA5 37201!!Estimate':'37201', 'ZCTA5 37203!!Estimate':'37203',
                                'ZCTA5 37204!!Estimate':'37204', 'ZCTA5 37205!!Estimate':'37205',
                                 'ZCTA5 37206!!Estimate':'37206', 'ZCTA5 37207!!Estimate':'37207',
                                'ZCTA5 37208!!Estimate':'37208', 'ZCTA5 37209!!Estimate':'37209',
                               'ZCTA5 37210!!Estimate':'37210', 'ZCTA5 37211!!Estimate':'37211',
                                 'ZCTA5 37212!!Estimate':'37212', 'ZCTA5 37213!!Estimate':'37213',
                                 'ZCTA5 37214!!Estimate':'37214', 'ZCTA5 37215!!Estimate':'37215',
                                'ZCTA5 37216!!Estimate':'37216', 'ZCTA5 37217!!Estimate':'37217',
                                'ZCTA5 37218!!Estimate':'37218', 'ZCTA5 37219!!Estimate':'37219',
                                'ZCTA5 37220!!Estimate':'37220', 'ZCTA5 37221!!Estimate':'37221',
                                'ZCTA5 37228!!Estimate':'37228', 'ZCTA5 37240!!Estimate': '37240',
                                 'ZCTA5 37243!!Estimate': '37243', 'ZCTA5 37246!!Estimate': '37246'}, inplace=True) 
df2011value

df2011value = df2011value.transpose()

df2011value.reset_index(level=0, inplace=True)

df2011value = df2011value.drop([df2011value.index[0]])

df2011value.rename(columns={'index': 'zip_code', 91: '2011 Less than 50,000', 92:'2011 50,000-99,999', 93:'2011 100,000-149,999', 94: '2011 150,000-199,999', 95: '2011 200,000-299,999',
                           96: '2011 300,000-499,999', 97: '2011 500,000-999,999', 98:'2011 1,000,000-+', 99: '2011 Median Value'}, inplace=True)
df2011value.head()
# Out:
#   zip_code 2011 Less than 50,000 2011 50,000-99,999 2011 100,000-149,999  \
# 1    37013                   521              1,374                7,447
# 2    37015                   497                858                1,413
# 3    37027                   117                 95                  318
# 4    37064                   393                376                  903
# 5    37072                   569                596                1,748
#
#   2011 150,000-199,999 2011 200,000-299,999 2011 300,000-499,999  \
# 1                5,266                2,712                  472
# 2                1,071                  782                  266
# 3                  679                1,865                6,339
# 4                1,649                3,672                4,785
# 5                2,277                1,697                1,088
#
#   2011 500,000-999,999 2011 1,000,000-+ 2011 Median Value
# 1                  166               39           148,000
# ...

# %%
#201 dataframe 
value_2015df = pd.DataFrame(housing_value_2015)

df2015value = housing_value_2015.iloc[[92, 93, 94, 95, 96, 97, 98, 99, 100], [0, 1, 5, 9, 13, 17, 21, 25, 29, 33, 37, 41, 45, 49,
                                                                        53, 57, 61, 65, 69, 73, 77, 81, 85, 89, 93, 97, 101,
                                                                        105, 109, 113, 117, 121, 125, 129, 133, 137, 141, 145, 
                                                                        149]]
                                                                         
df2015value.rename(columns={'ZCTA5 37013!!Estimate' : '37013', 'ZCTA5 37015!!Estimate':'37015',
                                'ZCTA5 37027!!Estimate':'37027', 'ZCTA5 37064!!Estimate':'37064',
                                 'ZCTA5 37072!!Estimate':'37072', 'ZCTA5 37076!!Estimate':'37076',
                                 'ZCTA5 37080!!Estimate':'37080', 'ZCTA5 37086!!Estimate':'37086',
                                 'ZCTA5 37115!!Estimate':'37115', 'ZCTA5 37122!!Estimate':'37122',
                                 'ZCTA5 37135!!Estimate':'37135', 'ZCTA5 37138!!Estimate':'37138',
                                 'ZCTA5 37143!!Estimate':'37143', 'ZCTA5 37189!!Estimate':'37189',
                               'ZCTA5 37201!!Estimate':'37201', 'ZCTA5 37203!!Estimate':'37203',
                                'ZCTA5 37204!!Estimate':'37204', 'ZCTA5 37205!!Estimate':'37205',
                                 'ZCTA5 37206!!Estimate':'37206', 'ZCTA5 37207!!Estimate':'37207',
                                'ZCTA5 37208!!Estimate':'37208', 'ZCTA5 37209!!Estimate':'37209',
                               'ZCTA5 37210!!Estimate':'37210', 'ZCTA5 37211!!Estimate':'37211',
                                 'ZCTA5 37212!!Estimate':'37212', 'ZCTA5 37213!!Estimate':'37213',
                                 'ZCTA5 37214!!Estimate':'37214', 'ZCTA5 37215!!Estimate':'37215',
                                'ZCTA5 37216!!Estimate':'37216', 'ZCTA5 37217!!Estimate':'37217',
                                'ZCTA5 37218!!Estimate':'37218', 'ZCTA5 37219!!Estimate':'37219',
                                'ZCTA5 37220!!Estimate':'37220', 'ZCTA5 37221!!Estimate':'37221',
                                'ZCTA5 37228!!Estimate':'37228', 'ZCTA5 37240!!Estimate': '37240',
                                 'ZCTA5 37243!!Estimate': '37243', 'ZCTA5 37246!!Estimate': '37246'}, inplace=True) 
df2015value

df2015value = df2015value.transpose()

df2015value.reset_index(level=0, inplace=True)

df2015value = df2015value.drop([df2015value.index[0]])

df2015value.rename(columns={'index': 'zip_code', 92: '2015 Less than 50,000', 93:'2015 50,000-99,999', 94:'2015 100,000-149,999', 95: '2015 150,000-199,999', 96: '2015 200,000-299,999',
                           97: '2015 300,000-499,999', 98: '2015 500,000-999,999', 99:'2015 1,000,000-+', 100: '2015 Median Value'}, inplace=True)
df2015value.head()
# Out:
#   zip_code 2015 Less than 50,000 2015 50,000-99,999 2015 100,000-149,999  \
# 1    37013                   620              1,800                6,982
# 2    37015                   399                972                1,472
# 3    37027                   219                106                  373
# 4    37064                   527                312                1,120
# 5    37072                   533                430                1,918
#
#   2015 150,000-199,999 2015 200,000-299,999 2015 300,000-499,999  \
# 1                5,845                2,160                  481
# 2                  870                  996                  249
# 3                  687                1,702                6,300
# 4                1,206                3,583                5,573
# 5                2,232                1,838                1,186
#
#   2015 500,000-999,999 2015 1,000,000-+ 2015 Median Value
# 1                  149               66           147,600
# ...

# %%
#2020 dataframe 
value_2020df = pd.DataFrame(housing_value_2020)

df2020value = housing_value_2020.iloc[[92, 93, 94, 95, 96, 97, 98, 99, 100], [0, 1, 5, 9, 13, 17, 21, 25, 29, 33, 37, 41, 45, 49,
                                                                        53, 57, 61, 65, 69, 73, 77, 81, 85, 89, 93, 97, 101,
                                                                        105, 109, 113, 117, 121, 125, 129, 133, 137, 141,145, 
                                                                        149]]
                                                                         
df2020value.rename(columns={'ZCTA5 37013!!Estimate' : '37013', 'ZCTA5 37015!!Estimate':'37015',
                                'ZCTA5 37027!!Estimate':'37027', 'ZCTA5 37064!!Estimate':'37064',
                                 'ZCTA5 37072!!Estimate':'37072', 'ZCTA5 37076!!Estimate':'37076',
                                 'ZCTA5 37080!!Estimate':'37080', 'ZCTA5 37086!!Estimate':'37086',
                                 'ZCTA5 37115!!Estimate':'37115', 'ZCTA5 37122!!Estimate':'37122',
                                 'ZCTA5 37135!!Estimate':'37135', 'ZCTA5 37138!!Estimate':'37138',
                                 'ZCTA5 37143!!Estimate':'37143', 'ZCTA5 37189!!Estimate':'37189',
                               'ZCTA5 37201!!Estimate':'37201', 'ZCTA5 37203!!Estimate':'37203',
                                'ZCTA5 37204!!Estimate':'37204', 'ZCTA5 37205!!Estimate':'37205',
                                 'ZCTA5 37206!!Estimate':'37206', 'ZCTA5 37207!!Estimate':'37207',
                                'ZCTA5 37208!!Estimate':'37208', 'ZCTA5 37209!!Estimate':'37209',
                               'ZCTA5 37210!!Estimate':'37210', 'ZCTA5 37211!!Estimate':'37211',
                                 'ZCTA5 37212!!Estimate':'37212', 'ZCTA5 37213!!Estimate':'37213',
                                 'ZCTA5 37214!!Estimate':'37214', 'ZCTA5 37215!!Estimate':'37215',
                                'ZCTA5 37216!!Estimate':'37216', 'ZCTA5 37217!!Estimate':'37217',
                                'ZCTA5 37218!!Estimate':'37218', 'ZCTA5 37219!!Estimate':'37219',
                                'ZCTA5 37220!!Estimate':'37220', 'ZCTA5 37221!!Estimate':'37221',
                                'ZCTA5 37228!!Estimate':'37228', 'ZCTA5 37240!!Estimate': '37240',
                                 'ZCTA5 37243!!Estimate': '37243', 'ZCTA5 37246!!Estimate': '37246'}, inplace=True) 
df2020value

df2020value = df2020value.transpose()

df2020value.reset_index(level=0, inplace=True)

df2020value = df2020value.drop([df2020value.index[0]])

df2020value.rename(columns={'index': 'zip_code', 92: '2020 Less than 50,000', 93:'2020 50,000-99,999', 94:'2020 100,000-149,999', 95: '2020 150,000-199,999', 96: '2020 200,000-299,999',
                           97: '2020 300,000-499,999', 98: '2020 500,000-999,999', 99:'2020 1,000,000-+', 100: '2020 Median Value'}, inplace=True)
df2020value.head()
# Out:
#   zip_code 2020 Less than 50,000 2020 50,000-99,999 2020 100,000-149,999  \
# 1    37013                   636                727                2,716
# 2    37015                   258                562                1,118
# 3    37027                   159                 49                  177
# 4    37064                   236                 70                  318
# 5    37072                   401                247                  693
#
#   2020 150,000-199,999 2020 200,000-299,999 2020 300,000-499,999  \
# 1                5,454                7,622                2,623
# 2                  992                1,253                  625
# 3                  262                  911                3,937
# 4                  522                1,768                7,203
# 5                1,677                3,288                2,160
#
#   2020 500,000-999,999 2020 1,000,000-+ 2020 Median Value
# 1                  241              188           205,800
# ...

# %%
#still need to merge all the dataframes together. Need to think of a better way to name these...but code for each individual dataframe is done.
#overall Final Income Dataframe
value_df = reduce(lambda left, right:
                      pd.merge(left, right,
                              on=['zip_code']),
                      [df2011value, df2015value, df2020value])
value_df.head()
# Out:
#   zip_code 2011 Less than 50,000 2011 50,000-99,999 2011 100,000-149,999  \
# 0    37013                   521              1,374                7,447
# 1    37015                   497                858                1,413
# 2    37027                   117                 95                  318
# 3    37064                   393                376                  903
# 4    37072                   569                596                1,748
#
#   2011 150,000-199,999 2011 200,000-299,999 2011 300,000-499,999  \
# 0                5,266                2,712                  472
# 1                1,071                  782                  266
# 2                  679                1,865                6,339
# 3                1,649                3,672                4,785
# 4                2,277                1,697                1,088
#
#   2011 500,000-999,999 2011 1,000,000-+ 2011 Median Value  ...  \
# 0                  166               39           148,000  ...
# ...

# %%
value_df.to_csv(r'C:\Users\sarah\Documents\DA7\projects\repos\breweries-middletn\data\value_dataframe.csv', index=False, header=True)
value_df
# Out:
#    zip_code 2011 Less than 50,000 2011 50,000-99,999 2011 100,000-149,999  \
# 0     37013                   521              1,374                7,447
# 1     37015                   497                858                1,413
# 2     37027                   117                 95                  318
# 3     37064                   393                376                  903
# 4     37072                   569                596                1,748
# 5     37076                   159                713                3,128
# 6     37080                    97                322                  608
# 7     37086                   290              1,182                3,530
# 8     37115                   386              1,497                3,314
# 9     37122                   626                330                1,765
# 10    37135                    36                 81                   56
# 11    37138                   206                668                2,055
# ...
