# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from bs4 import BeautifulSoup as BS
from csv import reader

# %%
# %matplotlib inline

# %%
#bringing in the URL 

URL = "https://www.bbb.org/us/tn/nashville/profile/brewers/jackalope-brewing-company-0573-37113394"
page = requests.get(URL)

# %%
#have to costume where I am coming from that's what the headers are doing
URL = 'https://www.bbb.org/us/tn/nashville/profile/brewers/jackalope-brewing-company-0573-37113394'

headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:105.0) Gecko/20100101 Firefox/105.0'
}

response = requests.get(URL, headers = headers)

# %%
print(response)
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '\ufeff<!DOCTYPE html><html class=no-js lang=en><head><link rel="shortcut icon" href=/favicon.ico type=image/vnd.microsoft.icon><meta charset=utf-8><meta http-equiv=x-ua-compatible content="ie=edge"><meta name=viewport content="width=device-width, initial-scale=1.0"><title>Jackalope Brewing Company | Better Business Bureau&#174; Profile</title><meta name=description content="This organization is not BBB accredited. Brewers in Nashville, TN. See BBB rating, reviews, complaints, &amp; more."><link rel=canonical href=https://www.bbb.org/us/tn/nashville/profile/brewers/jackalope-brewing-company-0573-37113394><meta property=og:description content="This organization is not BBB accredited. Brewers in Nashville, TN. See BBB rating, reviews, complaints, &amp; more."><meta property=og:title content="Jackalope Brewing Company |  Better Business Bureau® Profile"><meta property=og:url content="https://www.bbb.org/"><meta property=og:type content=website><meta property=og:image content=https://www
# ...

# %%
soup = BS(response.text)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
#  <head>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    Jackalope Brewing Company | Better Business Bureau® Profile
#   </title>
#   <meta content="This organization is not BBB accredited. Brewers in Nashville, TN. See BBB rating, reviews, complaints, &amp; more." name="description"/>
#   <link href="https://www.bbb.org/us/tn/nashville/profile/brewers/jackalope-brewing-company-0573-37113394" rel="canonical"/>
#   <meta content="This organization is not BBB accredited. Brewers in Nashville, TN. See BBB rating, reviews, complaints, &amp; more." property="og:description"/>
#   <meta content="Jackalope Brewing Company |  Better Business Bureau® Profile" property="og:title"/>
# ...

# %%
test_soup1 = soup.findAll('div', {'class': 'MuiGrid-root MuiGrid-container css-1d3bbye'})
test_soup1
# Out:
# [<div class="MuiGrid-root MuiGrid-container css-1d3bbye"><dt class="MuiGrid-root MuiGrid-item MuiGrid-grid-md-4 font-bold css-1c6r0y4">BBB File Opened<!-- -->:</dt><dd class="MuiGrid-root MuiGrid-item MuiGrid-grid-md-8 css-16cv23c">3/13/2015</dd></div>,
#  <div class="MuiGrid-root MuiGrid-container css-1d3bbye"><dt class="MuiGrid-root MuiGrid-item MuiGrid-grid-md-4 font-bold css-1c6r0y4">Years in Business<!-- -->:</dt><dd class="MuiGrid-root MuiGrid-item MuiGrid-grid-md-8 css-16cv23c">11</dd></div>,
#  <div class="MuiGrid-root MuiGrid-container css-1d3bbye"><dt class="MuiGrid-root MuiGrid-item MuiGrid-grid-md-4 font-bold css-1c6r0y4">Business Started<!-- -->:</dt><dd class="MuiGrid-root MuiGrid-item MuiGrid-grid-md-8 css-16cv23c">5/21/2011</dd></div>,
#  <div class="MuiGrid-root MuiGrid-container css-1d3bbye"><dt class="MuiGrid-root MuiGrid-item MuiGrid-grid-md-4 font-bold css-1c6r0y4"></dt><dd class="MuiGrid-root MuiGrid-item MuiGrid-grid-md-8 stack css-16cv23c"></dd></div>,
# ...

# %%
test_cleansoup1 = test_soup1[0].text.strip()
test_cleansoup1
# Out:
# 'BBB File Opened:3/13/2015'

# %%
tests1 = [bbb1.text.strip() for bbb1 in test_soup1]
tests1
# Out:
# ['BBB File Opened:3/13/2015',
#  'Years in Business:11',
#  'Business Started:5/21/2011',
#  '',
#  'Type of Entity:Limited Liability Company (LLC)',
#  'BBB File Opened:3/13/2015',
#  'Years in Business:11',
#  'Business Started:5/21/2011',
#  '',
#  'Type of Entity:Limited Liability Company (LLC)']

# %%
df = pd.DataFrame(tests1)
df

df.rename(columns={0: 'Jackalope Brewery Details'}, inplace=True)

df.loc[[0,1,2]]
# Out:
#     Jackalope Brewery Details
# 0   BBB File Opened:3/13/2015
# 1        Years in Business:11
# 2  Business Started:5/21/2011
