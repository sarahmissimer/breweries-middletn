# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from functools import reduce

# %matplotlib inline
pd.options.display.max_columns = None
# pd.options.display.max_rows = None

# %%
income_df = pd.read_csv("../data/income_dataframe.csv")

# %%
population_df = pd.read_csv("../data/population_dataframe.csv")

# %%
housing_value_df = pd.read_csv("../data/value_dataframe.csv")

# %%
yelp_df = pd.read_csv("../data/yelp_dataframe.csv")

# %%
breweries_df = reduce(lambda left, right:
                      pd.merge(left, right,
                              on=['zip_code']),
                      [yelp_df, income_df, population_df, housing_value_df])

breweries_df = breweries_df.drop(breweries_df.index[[6, 7, 8, 9, 10, 11, 12, 13, 15, 16, 17, 18, 20, 21, 24, 26, 28, 29,
                                                    30, 31, 38, 39, 40, 41, 43, 46, 47, 48, 49]])
breweries_df
# Out:
#                                         name  rating  review_count  \
# 0                       Tennessee Brew Works     4.5           457
# 1   Ole Smoky Distillery/Yee-Haw Brewing Co.     4.5           473
# 2      Jackalope Brewing Company - The Ranch     4.5            47
# 3                 TailGate Brewery Music Row     4.5           263
# 4                New Heights Brewing Company     4.5           100
# 5                      Hops & Crafts Taproom     4.5           134
# 14              Corsair Distillery & Taproom     4.5           235
# 19                              Diskin Cider     4.5           132
# 22                      Bearded Iris Brewing     4.5           205
# 23                      Monday Night Brewing     4.5            47
# 25                            The Picnic Tap     4.5            50
# 27                     Fait La Force Brewing     4.5            15
# 32            TailGate Brewery -  Germantown     4.5            19
# ...

# %%
zipcode37203 = breweries_df[breweries_df['zip_code'] == 37203]
zipcode37203
# Out:
#                                         name  rating  review_count  \
# 0                       Tennessee Brew Works     4.5           457
# 1   Ole Smoky Distillery/Yee-Haw Brewing Co.     4.5           473
# 2      Jackalope Brewing Company - The Ranch     4.5            47
# 3                 TailGate Brewery Music Row     4.5           263
# 4                New Heights Brewing Company     4.5           100
# 5                      Hops & Crafts Taproom     4.5           134
# 14              Corsair Distillery & Taproom     4.5           235
# 19                              Diskin Cider     4.5           132
#
#                     address1       city  zip_code state 2011 total household  \
# 0              809 Ewing Ave  Nashville     37203    TN                4,915
# 1              423 6th Ave S  Nashville     37203    TN                4,915
# 2            429B Houston St  Nashville     37203    TN                4,915
# ...

# %%
zipcode37208 =  breweries_df[breweries_df['zip_code'] == 37208]
zipcode37208
# Out:
#                     name  rating  review_count               address1  \
# 22  Bearded Iris Brewing     4.5           205       101 Van Buren St
# 23  Monday Night Brewing     4.5            47          1308 Adams St
# 25        The Picnic Tap     4.5            50  900 Rosa L Parks Blvd
#
#          city  zip_code state 2011 total household  \
# 22  Nashville     37208    TN                6,317
# 23  Nashville     37208    TN                6,317
# 25  Nashville     37208    TN                6,317
#
#    2011 household median income 2011 total families  \
# 22                       22,679               3,353
# 23                       22,679               3,353
# 25                       22,679               3,353
#
#    2011 families median income 2011 total married couple families  \
# 22                      31,166                                964
# 23                      31,166                                964
# ...

# %%
zipcode37201 = breweries_df[breweries_df['zip_code'] == 37201]
zipcode37201
# Out:
#                                 name  rating  review_count       address1  \
# 32    TailGate Brewery -  Germantown     4.5            19  915 3rd Ave N
# 33  Big Machine Brewery & Distillery     4.5            73  122 3rd Ave S
#
#          city  zip_code state 2011 total household  \
# 32  Nashville     37201    TN                  435
# 33  Nashville     37201    TN                  435
#
#    2011 household median income 2011 total families  \
# 32                       51,678                  61
# 33                       51,678                  61
#
#    2011 families median income 2011 total married couple families  \
# 32                      83,984                                 61
# 33                      83,984                                 61
#
#    2011 married couple families median income  \
# 32                                     83,984
# 33                                     83,984
#
# ...

# %%
zipcode37210 = breweries_df[breweries_df['zip_code'] == 37210]
zipcode37210
# Out:
#                      name  rating  review_count        address1       city  \
# 27  Fait La Force Brewing     4.5            15  1414 3rd Ave S  Nashville
#
#     zip_code state 2011 total household 2011 household median income  \
# 27     37210    TN                5,875                       25,662
#
#    2011 total families 2011 families median income  \
# 27               2,940                      29,353
#
#    2011 total married couple families  \
# 27                              1,310
#
#    2011 married couple families median income  \
# 27                                     40,263
#
#    2011 total non family households 2011 non family households median income  \
# 27                            2,935                                   21,602
#
#    2015 total household 2015 household median income 2015 total families  \
# 27                6,536                       29,035               3,053
#
#    2015 families median income 2015 total married couple families  \
# ...

# %%
zipcode37204 = breweries_df[breweries_df['zip_code'] == 37204]
zipcode37204
# Out:
#                                name  rating  review_count          address1  \
# 34  The Black Abbey Brewing Company     4.5           103     2952 Sidco Dr
# 35         12 South Taproom & Grill     3.5           364   2318 12th Ave S
# 36                     Craft Brewed     4.5           142    2502 8th Ave S
# 37              The Filling Station     4.5            70  1118 Halcyon Ave
#
#          city  zip_code state 2011 total household  \
# 34  Nashville     37204    TN                5,341
# 35  Nashville     37204    TN                5,341
# 36  Nashville     37204    TN                5,341
# 37  Nashville     37204    TN                5,341
#
#    2011 household median income 2011 total families  \
# 34                       62,818               2,492
# 35                       62,818               2,492
# 36                       62,818               2,492
# 37                       62,818               2,492
#
# ...

# %%
zipcode37206 = breweries_df[breweries_df['zip_code'] == 37206]
zipcode37206
# Out:
#                      name  rating  review_count     address1       city  \
# 42  Smith & Lentz Brewing     4.0           131  903 Main St  Nashville
#
#     zip_code state 2011 total household 2011 household median income  \
# 42     37206    TN               10,721                       32,697
#
#    2011 total families 2011 families median income  \
# 42               5,712                      36,049
#
#    2011 total married couple families  \
# 42                              2,924
#
#    2011 married couple families median income  \
# 42                                     58,149
#
#    2011 total non family households 2011 non family households median income  \
# 42                            5,009                                   26,976
#
#    2015 total household 2015 household median income 2015 total families  \
# 42               10,849                       43,782               5,848
#
#    2015 families median income 2015 total married couple families  \
# ...

# %%
zipcode37209 = breweries_df[breweries_df['zip_code'] == 37209]
zipcode37209
# Out:
#                           name  rating  review_count          address1  \
# 44  Blackstone Brewing Company     4.5            41  2312 Clifton Ave
#
#          city  zip_code state 2011 total household  \
# 44  Nashville     37209    TN               13,840
#
#    2011 household median income 2011 total families  \
# 44                       41,023               6,648
#
#    2011 families median income 2011 total married couple families  \
# 44                      48,039                              3,661
#
#    2011 married couple families median income  \
# 44                                     70,320
#
#    2011 total non family households 2011 non family households median income  \
# 44                            7,192                                   36,008
#
#    2015 total household 2015 household median income 2015 total families  \
# 44               14,132                       45,224               7,436
#
# ...

# %%
zipcode37213 = breweries_df[breweries_df['zip_code'] == 37213]
zipcode37213
# Out:
#                              name  rating  review_count      address1  \
# 45  Barrique Brewing And Blending     5.0            14  30 Oldham St
#
#          city  zip_code state 2011 total household  \
# 45  Nashville     37213    TN                   39
#
#    2011 household median income 2011 total families  \
# 45                       29,125                  16
#
#    2011 families median income 2011 total married couple families  \
# 45                           -                                 16
#
#    2011 married couple families median income  \
# 45                                          -
#
#    2011 total non family households 2011 non family households median income  \
# 45                               23                                   22,212
#
#    2015 total household 2015 household median income 2015 total families  \
# 45                    0                            -                   0
#
# ...
