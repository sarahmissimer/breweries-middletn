# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from functools import reduce

# %matplotlib inline
# pd.options.display.max_columns = None
# pd.options.display.max_rows = None

# %%
zipcodes_df = pd.read_csv("../data/zipcodes_df.csv")
zipcodes_df.head()
# Out:
#    zip_code 2011 total household 2011 household median income  \
# 0     37013               30,245                       48,198
# 1     37015                6,577                       45,018
# 2     37027               17,346                      113,696
# 3     37064               17,869                       72,798
# 4     37072               11,747                       51,353
#
#   2011 total families 2011 families median income  \
# 0              18,524                      57,348
# 1               4,545                      53,102
# 2              13,954                     131,049
# 3              13,549                      87,741
# 4               8,158                      61,942
#
#   2011 total married couple families  \
# 0                             12,583
# 1                              3,186
# 2                             12,646
# 3                             11,289
# 4                              6,211
#
# ...

# %%
zipcodes = zipcodes_df[['zip_code','2011 total household','2011 household median income', '2011 Median Value', '2011 population',
                       '2015 total household', '2015 household median income', '2015 Median Value', '2015 population',
                       '2020 total household', '2020 household median income', '2020 Median Value', '2020 population']]

zipcodes = zipcodes.replace(',', '', regex=True)
zipcodes

zipcodes = zipcodes.replace('-', '0', regex=True)
zipcodes

zipcodes['zip_code'] = zipcodes[['zip_code']].astype(str)
zipcodes

zipcodes[['2011 total household','2011 household median income', '2011 Median Value', '2011 population','2015 total household', '2015 household median income', '2015 Median Value', '2015 population','2020 total household', '2020 household median income', '2020 Median Value', '2020 population']] = zipcodes[['2011 total household','2011 household median income', '2011 Median Value', '2011 population', '2015 total household', '2015 household median income', '2015 Median Value', '2015 population','2020 total household', '2020 household median income', '2020 Median Value', '2020 population']].astype(int)
zipcodes

zipcodes = zipcodes.drop(zipcodes.index[36]).drop(zipcodes.index[37])
zipcodes
# Out:
#    zip_code  2011 total household  2011 household median income  \
# 0     37013                 30245                         48198
# 1     37015                  6577                         45018
# 2     37027                 17346                        113696
# 3     37064                 17869                         72798
# 4     37072                 11747                         51353
# 5     37076                 15205                         52428
# 6     37080                  2807                         58358
# 7     37086                 10221                         53803
# 8     37115                 16037                         36826
# 9     37122                 16301                         72445
# 10    37135                  2979                         97438
# 11    37138                  8878                         55741
# 12    37143                  1515                         64063
# 13    37189                  1323                         46068
# ...

# %%
#housing value
zipcodes['housing value avg growth'] = zipcodes[['2011 Median Value', '2015 Median Value', '2020 Median Value']].mean(1).round()

zipcodes['housing value avg growth rate'] = (zipcodes['2020 Median Value']-zipcodes['2011 Median Value'])/zipcodes['2011 Median Value']*100

#population
zipcodes['population avg growth'] = zipcodes[['2011 population', '2015 population', '2020 population']].mean(1).round()

zipcodes['population avg growth rate'] = (zipcodes['2020 population']-zipcodes['2011 population'])/zipcodes['2011 population']*100

#income
zipcodes['income avg growth'] = zipcodes[['2011 household median income', '2015 household median income', '2020 household median income']].mean(1).round()

zipcodes['income avg growth rate'] = (zipcodes['2020 household median income']-zipcodes['2011 household median income'])/zipcodes['2011 household median income']*100

zipcodes
# Out:
#    zip_code  2011 total household  2011 household median income  \
# 0     37013                 30245                         48198
# 1     37015                  6577                         45018
# 2     37027                 17346                        113696
# 3     37064                 17869                         72798
# 4     37072                 11747                         51353
# 5     37076                 15205                         52428
# 6     37080                  2807                         58358
# 7     37086                 10221                         53803
# 8     37115                 16037                         36826
# 9     37122                 16301                         72445
# 10    37135                  2979                         97438
# 11    37138                  8878                         55741
# 12    37143                  1515                         64063
# 13    37189                  1323                         46068
# ...

# %%
zipcodes_without = zipcodes.drop([15, 19, 20, 16, 21, 18, 22, 28, 25, 34])
zipcodes_without
# Out:
#    zip_code  2011 total household  2011 household median income  \
# 0     37013                 30245                         48198
# 1     37015                  6577                         45018
# 2     37027                 17346                        113696
# 3     37064                 17869                         72798
# 4     37072                 11747                         51353
# 5     37076                 15205                         52428
# 6     37080                  2807                         58358
# 7     37086                 10221                         53803
# 8     37115                 16037                         36826
# 9     37122                 16301                         72445
# 10    37135                  2979                         97438
# 11    37138                  8878                         55741
# 12    37143                  1515                         64063
# 13    37189                  1323                         46068
# ...

# %%
#housing value
zipcodes_without['housing value avg growth'] = zipcodes_without[['2011 Median Value', '2015 Median Value', '2020 Median Value']].mean(1).round()

zipcodes_without['housing value avg growth rate'] = (zipcodes_without['2020 Median Value']-zipcodes_without['2011 Median Value'])/zipcodes_without['2011 Median Value']*100

#population
zipcodes_without['population avg growth'] = zipcodes_without[['2011 population', '2015 population', '2020 population']].mean(1).round()

zipcodes_without['population avg growth rate'] = (zipcodes_without['2020 population']-zipcodes_without['2011 population'])/zipcodes_without['2011 population']*100

#income
zipcodes_without['income avg growth'] = zipcodes_without[['2011 household median income', '2015 household median income', '2020 household median income']].mean(1).round()

zipcodes_without['income avg growth rate'] = (zipcodes_without['2020 household median income']-zipcodes_without['2011 household median income'])/zipcodes_without['2011 household median income']*100

zipcodes_without
# Out:
#    zip_code  2011 total household  2011 household median income  \
# 0     37013                 30245                         48198
# 1     37015                  6577                         45018
# 2     37027                 17346                        113696
# 3     37064                 17869                         72798
# 4     37072                 11747                         51353
# 5     37076                 15205                         52428
# 6     37080                  2807                         58358
# 7     37086                 10221                         53803
# 8     37115                 16037                         36826
# 9     37122                 16301                         72445
# 10    37135                  2979                         97438
# 11    37138                  8878                         55741
# 12    37143                  1515                         64063
# 13    37189                  1323                         46068
# ...

# %%
brews_df = pd.read_csv("../data/breweries_final_dataframe.csv")
brews_df

brews = brews_df[['name', 'opening', 'neighborhood', 'address','zip_code','2011 total household','2011 household median income', '2011 Median Value', '2011 population',
                       '2015 total household', '2015 household median income', '2015 Median Value', '2015 population',
                       '2020 total household', '2020 household median income', '2020 Median Value', '2020 population']]

brews = brews.replace(',', '', regex=True)
brews

brews = brews.replace('-', '0', regex=True)
brews

brews['zip_code'] = brews[['zip_code']].astype(str)
brews

brews[['2011 total household','2011 household median income', '2011 Median Value', '2011 population','2015 total household', '2015 household median income', '2015 Median Value', '2015 population','2020 total household', '2020 household median income', '2020 Median Value', '2020 population']] = brews[['2011 total household','2011 household median income', '2011 Median Value', '2011 population', '2015 total household', '2015 household median income', '2015 Median Value', '2015 population','2020 total household', '2020 household median income', '2020 Median Value', '2020 population']].astype(int)
brews
# Out:
#                                      name  opening       neighborhood  \
# 0                    Tennessee Brew Works     2013              SoBro
# 1   Jackalope Brewing Company 0 The Ranch     2018  Wedgewood0Houston
# 2             New Heights Brewing Company     2016    South Nashville
# 3                  Southern Grist Brewing     2016     Cleveland Park
# 4               East Nashville Beer Works     2016     East Nashville
# 5                    Bearded Iris Brewing     2016        Germantown
# 6                    Monday Night Brewing     2021        Germantown
# 7         The Black Abbey Brewing Company     2013    South Nashville
# 8                      Fat Bottom Brewing     2012        The Nations
# 9            Bold Patriot Brewing Company     2020          Charlotte
# 10             Blackstone Brewing Company     2015            Midtown
# 11                 Czanns Brewing Company     2021        The Nations
# ...

# %%
brews['zip_code'].value_counts()
# Out:
# 37209    5
# 37203    3
# 37207    2
# 37208    2
# 37206    2
# 37204    1
# 37210    1
# 37216    1
# 37213    1
# 37228    1
# Name: zip_code, dtype: int64

# %%
brews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          19 non-null     object
#  1   opening                       19 non-null     int64
#  2   neighborhood                  19 non-null     object
#  3   address                       19 non-null     object
#  4   zip_code                      19 non-null     object
#  5   2011 total household          19 non-null     int32
#  6   2011 household median income  19 non-null     int32
#  7   2011 Median Value             19 non-null     int32
#  8   2011 population               19 non-null     int32
#  9   2015 total household          19 non-null     int32
#  10  2015 household median income  19 non-null     int32
#  11  2015 Median Value             19 non-null     int32
#  12  2015 population               19 non-null     int32
# ...

# %%
#housing value
brews['housing value avg growth'] = brews[['2011 Median Value', '2015 Median Value', '2020 Median Value']].mean(1).round()

brews['housing value avg growth rate'] = (brews['2020 Median Value']-brews['2011 Median Value'])/brews['2011 Median Value']*100

#population
brews['population avg growth'] = brews[['2011 population', '2015 population', '2020 population']].mean(1).round()

brews['population avg growth rate'] = (brews['2020 population']-brews['2011 population'])/brews['2011 population']*100

#income
brews['income avg growth'] = brews[['2011 household median income', '2015 household median income', '2020 household median income']].mean(1).round()

brews['income avg growth rate'] = (brews['2020 household median income']-brews['2011 household median income'])/brews['2011 household median income']*100

brews = brews.fillna(0)

brews
# Out:
#                                      name  opening       neighborhood  \
# 0                    Tennessee Brew Works     2013              SoBro
# 1   Jackalope Brewing Company 0 The Ranch     2018  Wedgewood0Houston
# 2             New Heights Brewing Company     2016    South Nashville
# 3                  Southern Grist Brewing     2016     Cleveland Park
# 4               East Nashville Beer Works     2016     East Nashville
# 5                    Bearded Iris Brewing     2016        Germantown
# 6                    Monday Night Brewing     2021        Germantown
# 7         The Black Abbey Brewing Company     2013    South Nashville
# 8                      Fat Bottom Brewing     2012        The Nations
# 9            Bold Patriot Brewing Company     2020          Charlotte
# 10             Blackstone Brewing Company     2015            Midtown
# 11                 Czanns Brewing Company     2021        The Nations
# ...

# %%
brews1 = brews[['zip_code','housing value avg growth rate','population avg growth rate', 'income avg growth rate']]
brews1
# Out:
#    zip_code  housing value avg growth rate  population avg growth rate  \
# 0     37203                      96.080454                   60.267559
# 1     37203                      96.080454                   60.267559
# 2     37203                      96.080454                   60.267559
# 3     37207                      58.758503                   22.064601
# 4     37207                      58.758503                   22.064601
# 5     37208                     169.504210                   12.516074
# 6     37208                     169.504210                   12.516074
# 7     37204                      98.976222                   28.063114
# 8     37209                     107.801418                    7.598283
# 9     37209                     107.801418                    7.598283
# 10    37209                     107.801418                    7.598283
# 11    37209                     107.801418                    7.598283
# ...

# %%
brews2 = brews1.drop_duplicates()
brews2
# Out:
#    zip_code  housing value avg growth rate  population avg growth rate  \
# 0     37203                      96.080454                   60.267559
# 3     37207                      58.758503                   22.064601
# 5     37208                     169.504210                   12.516074
# 7     37204                      98.976222                   28.063114
# 8     37209                     107.801418                    7.598283
# 13    37206                     128.027901                    4.978271
# 15    37210                     100.264550                   13.000807
# 16    37216                     106.030856                   -4.394036
# 17    37213                       0.000000                  -80.769231
# 18    37228                       0.000000                   11.859444
#
#     income avg growth rate
# 0               124.477797
# 3                64.337232
# 5               111.221835
# 7                43.197810
# 8                48.931087
# ...

# %%
brews2.mean(axis=0)
# Out:
# zip_code                         3.720337e+50
# housing value avg growth rate    8.654441e+03
# population avg growth rate       7.518488e+02
# income avg growth rate           7.043856e+03
# dtype: float64

# %%
96+107
# Out:
# 203

# %%
124+48
# Out:
# 172

# %%
zipcodes.to_csv(r'C:\Users\sarah\Documents\DA7\projects\repos\breweries-middletn\data\newzipcodes.csv', index=False, header=True)
zipcodes
# Out:
#    zip_code  2011 total household  2011 household median income  \
# 0     37013                 30245                         48198
# 1     37015                  6577                         45018
# 2     37027                 17346                        113696
# 3     37064                 17869                         72798
# 4     37072                 11747                         51353
# 5     37076                 15205                         52428
# 6     37080                  2807                         58358
# 7     37086                 10221                         53803
# 8     37115                 16037                         36826
# 9     37122                 16301                         72445
# 10    37135                  2979                         97438
# 11    37138                  8878                         55741
# 12    37143                  1515                         64063
# 13    37189                  1323                         46068
# ...

# %%
zipcodes_without.to_csv(r'C:\Users\sarah\Documents\DA7\projects\repos\breweries-middletn\data\newzipcodes_without.csv', index=False, header=True)
zipcodes_without
# Out:
#    zip_code  2011 total household  2011 household median income  \
# 0     37013                 30245                         48198
# 1     37015                  6577                         45018
# 2     37027                 17346                        113696
# 3     37064                 17869                         72798
# 4     37072                 11747                         51353
# 5     37076                 15205                         52428
# 6     37080                  2807                         58358
# 7     37086                 10221                         53803
# 8     37115                 16037                         36826
# 9     37122                 16301                         72445
# 10    37135                  2979                         97438
# 11    37138                  8878                         55741
# 12    37143                  1515                         64063
# 13    37189                  1323                         46068
# ...

# %%
zipcodes_without.mean(axis=0)
# Out:
# zip_code                         1.423591e+128
# 2011 total household              1.017665e+04
# 2011 household median income      6.116904e+04
# 2011 Median Value                 2.153462e+05
# 2011 population                   2.585731e+04
# 2015 total household              1.066212e+04
# 2015 household median income      6.166281e+04
# 2015 Median Value                 2.255115e+05
# 2015 population                   2.780496e+04
# 2020 total household              1.150008e+04
# 2020 household median income      7.700219e+04
# 2020 Median Value                 3.151346e+05
# 2020 population                   2.948269e+04
# housing value avg growth          2.519973e+05
# housing value avg growth rate     4.534964e+01
# population avg growth             2.771500e+04
# population avg growth rate        1.198294e+01
# income avg growth                 6.661138e+04
# income avg growth rate            2.670999e+01
# dtype: float64

# %%
brews.to_csv(r'C:\Users\sarah\Documents\DA7\projects\repos\breweries-middletn\data\newbrews.csv', index=False, header=True)
brews
# Out:
#                                      name  opening       neighborhood  \
# 0                    Tennessee Brew Works     2013              SoBro
# 1   Jackalope Brewing Company 0 The Ranch     2018  Wedgewood0Houston
# 2             New Heights Brewing Company     2016    South Nashville
# 3                  Southern Grist Brewing     2016     Cleveland Park
# 4               East Nashville Beer Works     2016     East Nashville
# 5                    Bearded Iris Brewing     2016        Germantown
# 6                    Monday Night Brewing     2021        Germantown
# 7         The Black Abbey Brewing Company     2013    South Nashville
# 8                      Fat Bottom Brewing     2012        The Nations
# 9            Bold Patriot Brewing Company     2020          Charlotte
# 10             Blackstone Brewing Company     2015            Midtown
# 11                 Czanns Brewing Company     2021        The Nations
# ...

# %%
brews1 = brews[['zip_code', 'name', 'opening', 'address']]
brews1
# Out:
#    zip_code                                   name  opening  \
# 0     37203                   Tennessee Brew Works     2013
# 1     37203  Jackalope Brewing Company 0 The Ranch     2018
# 2     37203            New Heights Brewing Company     2016
# 3     37207                 Southern Grist Brewing     2016
# 4     37207              East Nashville Beer Works     2016
# 5     37208                   Bearded Iris Brewing     2016
# 6     37208                   Monday Night Brewing     2021
# 7     37204        The Black Abbey Brewing Company     2013
# 8     37209                     Fat Bottom Brewing     2012
# 9     37209           Bold Patriot Brewing Company     2020
# 10    37209             Blackstone Brewing Company     2015
# 11    37209                 Czanns Brewing Company     2021
# 12    37209          Harding House Brewing Company     2018
# 13    37206                    Crazy Gnome Brewery     2020
# 14    37206                  Smith & Lentz Brewing     2015
# ...

# %%
#going to try to merge my zipcodes df with this one. need this to work so my dashboards can talk with each other. 


master = pd.merge(zipcodes, brews1, on='zip_code', how='outer')
master

# master.fillna(0)
# Out:
#    zip_code  2011 total household  2011 household median income  \
# 0     37013                 30245                         48198
# 1     37015                  6577                         45018
# 2     37027                 17346                        113696
# 3     37064                 17869                         72798
# 4     37072                 11747                         51353
# 5     37076                 15205                         52428
# 6     37080                  2807                         58358
# 7     37086                 10221                         53803
# 8     37115                 16037                         36826
# 9     37122                 16301                         72445
# 10    37135                  2979                         97438
# 11    37138                  8878                         55741
# 12    37143                  1515                         64063
# 13    37189                  1323                         46068
# ...

# %%
master['zip_code'].value_counts()
# Out:
# 37209    5
# 37203    3
# 37206    2
# 37207    2
# 37208    2
# 37219    1
# 37218    1
# 37217    1
# 37216    1
# 37220    1
# 37214    1
# 37213    1
# 37212    1
# 37211    1
# 37210    1
# 37221    1
# 37228    1
# 37215    1
# 37013    1
# 37015    1
# 37115    1
# 37027    1
# 37064    1
# 37072    1
# 37076    1
# 37080    1
# 37086    1
# 37122    1
# 37205    1
# 37135    1
# 37138    1
# 37143    1
# 37189    1
# 37201    1
# 37204    1
# 37240    1
# Name: zip_code, dtype: int64

# %%
master.to_csv(r'C:\Users\sarah\Documents\DA7\projects\repos\breweries-middletn\data\master.csv', index=False, header=True)
master
# Out:
#    zip_code  2011 total household  2011 household median income  \
# 0     37013                 30245                         48198
# 1     37015                  6577                         45018
# 2     37027                 17346                        113696
# 3     37064                 17869                         72798
# 4     37072                 11747                         51353
# 5     37076                 15205                         52428
# 6     37080                  2807                         58358
# 7     37086                 10221                         53803
# 8     37115                 16037                         36826
# 9     37122                 16301                         72445
# 10    37135                  2979                         97438
# 11    37138                  8878                         55741
# 12    37143                  1515                         64063
# 13    37189                  1323                         46068
# ...

# %%
brews2011 = brews[['name', 'neighborhood', 'zip_code', '2011 total household', '2011 household median income','2011 Median Value']]
brews2011
# Out:
#                                      name       neighborhood zip_code  \
# 0                    Tennessee Brew Works              SoBro    37203
# 1   Jackalope Brewing Company 0 The Ranch  Wedgewood0Houston    37203
# 2             New Heights Brewing Company    South Nashville    37203
# 3                  Southern Grist Brewing     Cleveland Park    37207
# 4               East Nashville Beer Works     East Nashville    37207
# 5                    Bearded Iris Brewing        Germantown     37208
# 6                    Monday Night Brewing        Germantown     37208
# 7         The Black Abbey Brewing Company    South Nashville    37204
# 8                      Fat Bottom Brewing        The Nations    37209
# 9            Bold Patriot Brewing Company          Charlotte    37209
# 10             Blackstone Brewing Company            Midtown    37209
# 11                 Czanns Brewing Company        The Nations    37209
# ...

# %%
brews2011.to_csv(r'C:\Users\sarah\Documents\DA7\projects\repos\breweries-middletn\data\brews2011.csv', index=False, header=True)
brews2011
# Out:
#                                      name       neighborhood zip_code  \
# 0                    Tennessee Brew Works              SoBro    37203
# 1   Jackalope Brewing Company 0 The Ranch  Wedgewood0Houston    37203
# 2             New Heights Brewing Company    South Nashville    37203
# 3                  Southern Grist Brewing     Cleveland Park    37207
# 4               East Nashville Beer Works     East Nashville    37207
# 5                    Bearded Iris Brewing        Germantown     37208
# 6                    Monday Night Brewing        Germantown     37208
# 7         The Black Abbey Brewing Company    South Nashville    37204
# 8                      Fat Bottom Brewing        The Nations    37209
# 9            Bold Patriot Brewing Company          Charlotte    37209
# 10             Blackstone Brewing Company            Midtown    37209
# 11                 Czanns Brewing Company        The Nations    37209
# ...

# %%
brews2015 = brews[['name', 'neighborhood', 'zip_code', '2015 total household', '2015 household median income','2015 Median Value']]
brews2015
# Out:
#                                      name       neighborhood zip_code  \
# 0                    Tennessee Brew Works              SoBro    37203
# 1   Jackalope Brewing Company 0 The Ranch  Wedgewood0Houston    37203
# 2             New Heights Brewing Company    South Nashville    37203
# 3                  Southern Grist Brewing     Cleveland Park    37207
# 4               East Nashville Beer Works     East Nashville    37207
# 5                    Bearded Iris Brewing        Germantown     37208
# 6                    Monday Night Brewing        Germantown     37208
# 7         The Black Abbey Brewing Company    South Nashville    37204
# 8                      Fat Bottom Brewing        The Nations    37209
# 9            Bold Patriot Brewing Company          Charlotte    37209
# 10             Blackstone Brewing Company            Midtown    37209
# 11                 Czanns Brewing Company        The Nations    37209
# ...

# %%
brews2015.to_csv(r'C:\Users\sarah\Documents\DA7\projects\repos\breweries-middletn\data\brews2015.csv', index=False, header=True)
brews2015
# Out:
#                                      name       neighborhood zip_code  \
# 0                    Tennessee Brew Works              SoBro    37203
# 1   Jackalope Brewing Company 0 The Ranch  Wedgewood0Houston    37203
# 2             New Heights Brewing Company    South Nashville    37203
# 3                  Southern Grist Brewing     Cleveland Park    37207
# 4               East Nashville Beer Works     East Nashville    37207
# 5                    Bearded Iris Brewing        Germantown     37208
# 6                    Monday Night Brewing        Germantown     37208
# 7         The Black Abbey Brewing Company    South Nashville    37204
# 8                      Fat Bottom Brewing        The Nations    37209
# 9            Bold Patriot Brewing Company          Charlotte    37209
# 10             Blackstone Brewing Company            Midtown    37209
# 11                 Czanns Brewing Company        The Nations    37209
# ...

# %%
brews2020 = brews[['name', 'neighborhood', 'zip_code', '2020 total household', '2020 household median income','2020 Median Value']]
brews2020
# Out:
#                                      name       neighborhood zip_code  \
# 0                    Tennessee Brew Works              SoBro    37203
# 1   Jackalope Brewing Company 0 The Ranch  Wedgewood0Houston    37203
# 2             New Heights Brewing Company    South Nashville    37203
# 3                  Southern Grist Brewing     Cleveland Park    37207
# 4               East Nashville Beer Works     East Nashville    37207
# 5                    Bearded Iris Brewing        Germantown     37208
# 6                    Monday Night Brewing        Germantown     37208
# 7         The Black Abbey Brewing Company    South Nashville    37204
# 8                      Fat Bottom Brewing        The Nations    37209
# 9            Bold Patriot Brewing Company          Charlotte    37209
# 10             Blackstone Brewing Company            Midtown    37209
# 11                 Czanns Brewing Company        The Nations    37209
# ...

# %%
brews2020.to_csv(r'C:\Users\sarah\Documents\DA7\projects\repos\breweries-middletn\data\brews2020.csv', index=False, header=True)
brews2020
# Out:
#                                      name       neighborhood zip_code  \
# 0                    Tennessee Brew Works              SoBro    37203
# 1   Jackalope Brewing Company 0 The Ranch  Wedgewood0Houston    37203
# 2             New Heights Brewing Company    South Nashville    37203
# 3                  Southern Grist Brewing     Cleveland Park    37207
# 4               East Nashville Beer Works     East Nashville    37207
# 5                    Bearded Iris Brewing        Germantown     37208
# 6                    Monday Night Brewing        Germantown     37208
# 7         The Black Abbey Brewing Company    South Nashville    37204
# 8                      Fat Bottom Brewing        The Nations    37209
# 9            Bold Patriot Brewing Company          Charlotte    37209
# 10             Blackstone Brewing Company            Midtown    37209
# 11                 Czanns Brewing Company        The Nations    37209
# ...

# %%
brews2011 = pd.read_csv("../data/brews2011.csv")
brews2011

year = ['2011','2011','2011','2011','2011','2011','2011','2011','2011','2011','2011','2011','2011','2011','2011','2011','2011','2011','2011']

brews2011['year'] = year
brews2011
# Out:
#                                      name       neighborhood  zip_code  \
# 0                    Tennessee Brew Works              SoBro     37203
# 1   Jackalope Brewing Company 0 The Ranch  Wedgewood0Houston     37203
# 2             New Heights Brewing Company    South Nashville     37203
# 3                  Southern Grist Brewing     Cleveland Park     37207
# 4               East Nashville Beer Works     East Nashville     37207
# 5                    Bearded Iris Brewing        Germantown      37208
# 6                    Monday Night Brewing        Germantown      37208
# 7         The Black Abbey Brewing Company    South Nashville     37204
# 8                      Fat Bottom Brewing        The Nations     37209
# 9            Bold Patriot Brewing Company          Charlotte     37209
# 10             Blackstone Brewing Company            Midtown     37209
# 11                 Czanns Brewing Company        The Nations     37209
# ...

# %%
brews2015 = pd.read_csv("../data/brews2015.csv")
brews2015

year = ['2015','2015','2015','2015','2015','2015','2015','2015','2015','2015','2015','2015','2015','2015','2015','2015','2015','2015','2015']

brews2015['year'] = year
brews2015
# Out:
#                                      name       neighborhood  zip_code  \
# 0                    Tennessee Brew Works              SoBro     37203
# 1   Jackalope Brewing Company 0 The Ranch  Wedgewood0Houston     37203
# 2             New Heights Brewing Company    South Nashville     37203
# 3                  Southern Grist Brewing     Cleveland Park     37207
# 4               East Nashville Beer Works     East Nashville     37207
# 5                    Bearded Iris Brewing        Germantown      37208
# 6                    Monday Night Brewing        Germantown      37208
# 7         The Black Abbey Brewing Company    South Nashville     37204
# 8                      Fat Bottom Brewing        The Nations     37209
# 9            Bold Patriot Brewing Company          Charlotte     37209
# 10             Blackstone Brewing Company            Midtown     37209
# 11                 Czanns Brewing Company        The Nations     37209
# ...

# %%
brews2020 = pd.read_csv("../data/brews2020.csv")
brews2020

year = ['2020','2020','2020','2020','2020','2020','2020','2020','2020','2020','2020','2020','2020','2020','2020','2020','2020','2020','2020']

brews2020['year'] = year
brews2020
# Out:
#                                      name       neighborhood  zip_code  \
# 0                    Tennessee Brew Works              SoBro     37203
# 1   Jackalope Brewing Company 0 The Ranch  Wedgewood0Houston     37203
# 2             New Heights Brewing Company    South Nashville     37203
# 3                  Southern Grist Brewing     Cleveland Park     37207
# 4               East Nashville Beer Works     East Nashville     37207
# 5                    Bearded Iris Brewing        Germantown      37208
# 6                    Monday Night Brewing        Germantown      37208
# 7         The Black Abbey Brewing Company    South Nashville     37204
# 8                      Fat Bottom Brewing        The Nations     37209
# 9            Bold Patriot Brewing Company          Charlotte     37209
# 10             Blackstone Brewing Company            Midtown     37209
# 11                 Czanns Brewing Company        The Nations     37209
# ...

# %%
master_years = pd.merge(pd.merge(brews2011, brews2015, on=['zip_code', 'name', 'neighborhood']), brews2020, on=['zip_code', 'name', 'neighborhood'])
master_years
# Out:
#                                      name       neighborhood  zip_code  \
# 0                    Tennessee Brew Works              SoBro     37203
# 1   Jackalope Brewing Company 0 The Ranch  Wedgewood0Houston     37203
# 2             New Heights Brewing Company    South Nashville     37203
# 3                  Southern Grist Brewing     Cleveland Park     37207
# 4               East Nashville Beer Works     East Nashville     37207
# 5                    Bearded Iris Brewing        Germantown      37208
# 6                    Monday Night Brewing        Germantown      37208
# 7         The Black Abbey Brewing Company    South Nashville     37204
# 8                      Fat Bottom Brewing        The Nations     37209
# 9            Bold Patriot Brewing Company          Charlotte     37209
# 10             Blackstone Brewing Company            Midtown     37209
# 11                 Czanns Brewing Company        The Nations     37209
# ...

# %%
master_years.to_csv(r'C:\Users\sarah\Documents\DA7\projects\repos\breweries-middletn\data\master_years.csv', index=False, header=True)
master_years
# Out:
#                                      name       neighborhood  zip_code  \
# 0                    Tennessee Brew Works              SoBro     37203
# 1   Jackalope Brewing Company 0 The Ranch  Wedgewood0Houston     37203
# 2             New Heights Brewing Company    South Nashville     37203
# 3                  Southern Grist Brewing     Cleveland Park     37207
# 4               East Nashville Beer Works     East Nashville     37207
# 5                    Bearded Iris Brewing        Germantown      37208
# 6                    Monday Night Brewing        Germantown      37208
# 7         The Black Abbey Brewing Company    South Nashville     37204
# 8                      Fat Bottom Brewing        The Nations     37209
# 9            Bold Patriot Brewing Company          Charlotte     37209
# 10             Blackstone Brewing Company            Midtown     37209
# 11                 Czanns Brewing Company        The Nations     37209
# ...

# %%
master_years2 = pd.concat([brews2011, brews2015, brews2020], axis=0)
master_years2
# Out:
#                                      name       neighborhood  zip_code  \
# 0                    Tennessee Brew Works              SoBro     37203
# 1   Jackalope Brewing Company 0 The Ranch  Wedgewood0Houston     37203
# 2             New Heights Brewing Company    South Nashville     37203
# 3                  Southern Grist Brewing     Cleveland Park     37207
# 4               East Nashville Beer Works     East Nashville     37207
# 5                    Bearded Iris Brewing        Germantown      37208
# 6                    Monday Night Brewing        Germantown      37208
# 7         The Black Abbey Brewing Company    South Nashville     37204
# 8                      Fat Bottom Brewing        The Nations     37209
# 9            Bold Patriot Brewing Company          Charlotte     37209
# 10             Blackstone Brewing Company            Midtown     37209
# 11                 Czanns Brewing Company        The Nations     37209
# ...

# %%
master_years2.to_csv(r'C:\Users\sarah\Documents\DA7\projects\repos\breweries-middletn\data\master_years2.csv', index=False, header=True)
master_years2
# Out:
#                                      name       neighborhood  zip_code  \
# 0                    Tennessee Brew Works              SoBro     37203
# 1   Jackalope Brewing Company 0 The Ranch  Wedgewood0Houston     37203
# 2             New Heights Brewing Company    South Nashville     37203
# 3                  Southern Grist Brewing     Cleveland Park     37207
# 4               East Nashville Beer Works     East Nashville     37207
# 5                    Bearded Iris Brewing        Germantown      37208
# 6                    Monday Night Brewing        Germantown      37208
# 7         The Black Abbey Brewing Company    South Nashville     37204
# 8                      Fat Bottom Brewing        The Nations     37209
# 9            Bold Patriot Brewing Company          Charlotte     37209
# 10             Blackstone Brewing Company            Midtown     37209
# 11                 Czanns Brewing Company        The Nations     37209
# ...

# %%
# without_df2['average growth'] = without_df2[['2011 household median income', '2015 household median income', '2020 household median income']].mean(1).round()

# without_df2['growth rate'] = (without_df2['2020 household median income']-without_df2['2011 household median income'])/without_df2['2011 household median income']*100

# without_df2.head()

# master_years2['average income growth'] = master_years2[['2011 household median income','2015 household median income','2020 household median income']].mean(1).round()
# master_years2

# master_years2['average population growth'] = master_years2[['2011 total household','2015 total household','2020 total household']].mean(1).round()
# master_years2

# master_years2['average house value growth'] = master_years2[['2011 Median Value','2015 Median Value','2020 Median Value']].mean(1).round()
# master_years2

# master_years2['income growth rate'] = (master_years2['2020 household median income']-master_years2['2011 household median income'])/master_years2['2011 household median income']*100
# master_years2
