# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
#need to import all the csv files 

age_sex2011 = pd.read_csv("../data/age_sex_davidsoncounty2011.csv")
age_sex2011.head()
# Out:
#      Label (Grouping) ZCTA5 37013!!Total!!Estimate  \
# 0    Total population                       76,983
# 1                 AGE                          NaN
# 2       Under 5 years                         8.6%
# 3        5 to 9 years                         7.0%
# 4      10 to 14 years                         6.1%
#
#   ZCTA5 37013!!Total!!Margin of Error ZCTA5 37013!!Male!!Estimate  \
# 0                              ±1,951                      36,783
# 1                                 NaN                         NaN
# 2                                ±0.6                        8.9%
# 3                                ±0.6                        6.7%
# 4                                ±0.6                        6.3%
#
#   ZCTA5 37013!!Male!!Margin of Error ZCTA5 37013!!Female!!Estimate  \
# 0                             ±1,121                        40,200
# 1                                NaN                           NaN
# 2                               ±1.1                          8.4%
# 3                               ±0.8                          7.3%
# 4                               ±1.0                          5.9%
#
#   ZCTA5 37013!!Female!!Margin of Error ZCTA5 37015!!Total!!Estimate  \
# 0                               ±1,275                       16,976
# 1                                  NaN                          NaN
# 2                                 ±0.8                         6.9%
# 3                                 ±1.1                         6.9%
# 4                                 ±0.9                         6.2%
#
#   ZCTA5 37015!!Total!!Margin of Error ZCTA5 37015!!Male!!Estimate  ...  \
# 0                                ±780                       8,678  ...
# 1                                 NaN                         NaN  ...
# 2                                ±1.1                        7.0%  ...
# 3                                ±1.2                        7.3%  ...
# 4                                ±1.1                        7.6%  ...
#
#   ZCTA5 37243!!Male!!Estimate ZCTA5 37243!!Male!!Margin of Error  \
# 0                           0                                ±95
# 1                         NaN                                NaN
# 2                           -                                 **
# 3                           -                                 **
# 4                           -                                 **
#
#   ZCTA5 37243!!Female!!Estimate ZCTA5 37243!!Female!!Margin of Error  \
# 0                             0                                  ±95
# 1                           NaN                                  NaN
# 2                             -                                   **
# 3                             -                                   **
# 4                             -                                   **
#
#   ZCTA5 37246!!Total!!Estimate ZCTA5 37246!!Total!!Margin of Error  \
# 0                            0                                 ±95
# 1                          NaN                                 NaN
# 2                            -                                  **
# 3                            -                                  **
# 4                            -                                  **
#
#   ZCTA5 37246!!Male!!Estimate ZCTA5 37246!!Male!!Margin of Error  \
# 0                           0                                ±95
# 1                         NaN                                NaN
# 2                           -                                 **
# 3                           -                                 **
# 4                           -                                 **
#
#   ZCTA5 37246!!Female!!Estimate ZCTA5 37246!!Female!!Margin of Error
# 0                             0                                  ±95
# 1                           NaN                                  NaN
# 2                             -                                   **
# 3                             -                                   **
# 4                             -                                   **
#
# [5 rows x 229 columns]

# %%
age_sex2011.dropna().head()
# Out:
#      Label (Grouping) ZCTA5 37013!!Total!!Estimate  \
# 0    Total population                       76,983
# 2       Under 5 years                         8.6%
# 3        5 to 9 years                         7.0%
# 4      10 to 14 years                         6.1%
# 5      15 to 19 years                         5.7%
#
#   ZCTA5 37013!!Total!!Margin of Error ZCTA5 37013!!Male!!Estimate  \
# 0                              ±1,951                      36,783
# 2                                ±0.6                        8.9%
# 3                                ±0.6                        6.7%
# 4                                ±0.6                        6.3%
# 5                                ±0.8                        5.6%
#
#   ZCTA5 37013!!Male!!Margin of Error ZCTA5 37013!!Female!!Estimate  \
# 0                             ±1,121                        40,200
# 2                               ±1.1                          8.4%
# 3                               ±0.8                          7.3%
# 4                               ±1.0                          5.9%
# 5                               ±0.9                          5.8%
#
#   ZCTA5 37013!!Female!!Margin of Error ZCTA5 37015!!Total!!Estimate  \
# 0                               ±1,275                       16,976
# 2                                 ±0.8                         6.9%
# 3                                 ±1.1                         6.9%
# 4                                 ±0.9                         6.2%
# 5                                 ±0.9                         6.5%
#
#   ZCTA5 37015!!Total!!Margin of Error ZCTA5 37015!!Male!!Estimate  ...  \
# 0                                ±780                       8,678  ...
# 2                                ±1.1                        7.0%  ...
# 3                                ±1.2                        7.3%  ...
# 4                                ±1.1                        7.6%  ...
# 5                                ±1.0                        5.6%  ...
#
#   ZCTA5 37243!!Male!!Estimate ZCTA5 37243!!Male!!Margin of Error  \
# 0                           0                                ±95
# 2                           -                                 **
# 3                           -                                 **
# 4                           -                                 **
# 5                           -                                 **
#
#   ZCTA5 37243!!Female!!Estimate ZCTA5 37243!!Female!!Margin of Error  \
# 0                             0                                  ±95
# 2                             -                                   **
# 3                             -                                   **
# 4                             -                                   **
# 5                             -                                   **
#
#   ZCTA5 37246!!Total!!Estimate ZCTA5 37246!!Total!!Margin of Error  \
# 0                            0                                 ±95
# 2                            -                                  **
# 3                            -                                  **
# 4                            -                                  **
# 5                            -                                  **
#
#   ZCTA5 37246!!Male!!Estimate ZCTA5 37246!!Male!!Margin of Error  \
# 0                           0                                ±95
# 2                           -                                 **
# 3                           -                                 **
# 4                           -                                 **
# 5                           -                                 **
#
#   ZCTA5 37246!!Female!!Estimate ZCTA5 37246!!Female!!Margin of Error
# 0                             0                                  ±95
# 2                             -                                   **
# 3                             -                                   **
# 4                             -                                   **
# 5                             -                                   **
#
# [5 rows x 229 columns]

# %%
age_sex2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Columns: 229 entries, Label (Grouping) to ZCTA5 37246!!Female!!Margin of Error
# dtypes: object(229)
# memory usage: 71.7+ KB
